# %% [markdown]
# <a href="https://colab.research.google.com/github/G2454/Projeto-Processamento-de-Imagens/blob/main/janela_principal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
import ipywidgets as widgets
from IPython.display import display, HTML, Javascript
from sklearn import preprocessing
import numpy as np
import sys
import warnings
warnings.filterwarnings("ignore", message="Your PyDataset")
warnings.filterwarnings('ignore', category=UserWarning, module='tensorflow')
warnings.filterwarnings("ignore")
import tensorflow as tf
import os
import logging
# Define o nível de log da Tensorflow para 3 e ignora os demais níveis
logging.disable(logging.WARNING)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # 0 (INFO), 1 (WARNING), 2 (ERROR), 3 (FATAL)

#####################
# MONTAGEM DO DRIVE #
#####################
from google.colab import drive
if not os.path.ismount('/content/drive'):
    print("Montando o Google Drive...")
    drive.mount('/content/drive')

###########################
# CARREGAMENTO DE MÓDULOS #
###########################

# Caminho dos módulos do projeto armazenados no Google Drive
caminho_modulos = '/content/drive/MyDrive/Colab Notebooks/VC/Classificacao_CNN/modulos'
from pydoc import importfile
# Importação de módulos Python
modulo_cnn_treino = importfile(caminho_modulos+'/classificadores/cnn_treino.py')
modulo_cnn_teste = importfile(caminho_modulos+'/classificadores/cnn_teste.py')

########################################################################
# CAMINHOS E VARIAVES GLOBAIS
########################################################################

caminho_base = '/content/drive/MyDrive/Colab Notebooks/VC/Classificacao_CNN'
caminho_todos_datasets = caminho_base + '/datasets/'
selected_dataset = 'coffee_bean'
caminho_imagens_treino = caminho_todos_datasets + selected_dataset + '/train/'
caminho_imagens_val = caminho_todos_datasets + selected_dataset + '/val/'
caminho_imagens_teste = caminho_todos_datasets + selected_dataset + '/test/'
caminho_log = caminho_base + '/log/logger.csv'
caminho_checkpoints = caminho_base + '/checkpoints/cp.weights.h5'
caminho_modelo_cnn_treinado = caminho_base + '/modelos/resnet50.keras'
caminho_resultados = caminho_base + '/resultados/'
forma_img = (224,224,3)
metrica = 'accuracy'
tam_lote = 32
num_epocas = 20

########################################################################
# FUNÇÕES DE EXECUÇÃO DOS PIPELINES
########################################################################

def pipeline_treinamento():
    print("\n\n")
    ########################################################################
    # OBTEM AS IMAGENS DE TREINAMENTO E VALIDACAO
    ########################################################################

    imagens_treino = modulo_cnn_treino.obter_imagens_treino(
        caminho_imagens_treino,
        forma_img,
        tam_lote)
    imagens_validacao = modulo_cnn_treino.obter_imagens_validacao(
        caminho_imagens_val,
        forma_img,
        tam_lote)
    num_classes = imagens_treino.num_classes

    ########################################################################
    # OBTEM E COMPILA O MODELO
    ########################################################################

    modelo_cnn = modulo_cnn_treino.obter_modelo_cnn(num_classes)
    modelo_compilado = modulo_cnn_treino.compilar_modelo_cnn(modelo_cnn, metrica)

    ########################################################################
    # OBTEM A LISTA DE CALLBACKS
    ########################################################################

    cp = modulo_cnn_treino.obter_checkpoint_callback(caminho_checkpoints)
    log = modulo_cnn_treino.obter_log_callback(caminho_log)
    lr = modulo_cnn_treino.obter_reduce_lr_callback()
    es = modulo_cnn_treino.obter_early_stop_callback()
    lista_callbacks = [cp, log, lr, es]

    ########################################################################
    # TREINA O MODELO
    ########################################################################

    modelo_treinado, historico = modulo_cnn_treino.treinar_modelo(modelo_compilado, imagens_treino, imagens_validacao, num_epocas, caminho_checkpoints,lista_callbacks)

    ########################################################################
    # SALVA MODELO
    ########################################################################

    modulo_cnn_treino.salvar_modelo(modelo_treinado, caminho_modelo_cnn_treinado)

    ########################################################################
    # PLOTA E SALVA HISTÓRICO DO TREINAMENTO
    ########################################################################

    modulo_cnn_treino.plot_historico(historico,metrica,caminho_resultados)


def pipeline_teste():
    print("\n\n")
    ########################################################################
    # OBTEM AS IMAGENS E OS ROTULOS DE TESTE
    ########################################################################

    imagens_teste = modulo_cnn_teste.obter_imagens_teste(
        caminho_imagens_teste,
        forma_img,
        tam_lote)
    rotulos_verdadeiros = imagens_teste.classes
    nomes_das_classes = list(imagens_teste.class_indices.keys())

    ########################################################################
    # CARREGA O MODELO TREINADO A PARTIR DE UM ARQUIVO
    ########################################################################

    modelo_treinado = modulo_cnn_teste.carregar_modelo_cnn_treinado(
        caminho_modelo_cnn_treinado)

    ########################################################################
    # TESTA O MODELO
    ########################################################################

    rotulos_previstos = modulo_cnn_teste.testar_modelo(modelo_treinado, imagens_teste)

    ########################################################################
    # PLOTA E SALVA RESULTADOS DO MODELO
    ########################################################################

    modulo_cnn_teste.matriz_confusao(
        rotulos_verdadeiros,
        rotulos_previstos,
        nomes_das_classes,
        caminho_resultados)

    modulo_cnn_teste.plot_metrica(
        rotulos_verdadeiros,
        rotulos_previstos,
        'precision',
        nomes_das_classes,
        caminho_resultados)

    modulo_cnn_teste.plot_metrica(
        rotulos_verdadeiros,
        rotulos_previstos,
        'recall',
        nomes_das_classes,
        caminho_resultados)

    modulo_cnn_teste.plot_metrica(
        rotulos_verdadeiros,
        rotulos_previstos,
        'f1-score',
        nomes_das_classes,
        caminho_resultados)

########################################################################
# MENU PARA ESCOLHA DOS PIPELINES
 ########################################################################

def menu():
    while True:
        print("\n")
        print("Selecione uma opção:")
        print("1. Executar o pipeline de treinamento")
        print("2. Executar o pipeline de teste")
        print("3. Sair")
        print("\n")

        escolha = input("Digite o número da sua escolha: ")

        if escolha == '1':
            pipeline_treinamento()
        elif escolha == '2':
            pipeline_teste()
        elif escolha == '3':
            print("Execução finalizada!")
            break
        else:
            print("Escolha inválida. Por favor, selecione uma opção válida.")

# Chamada do menu para que o usuário faça a escolha
menu()


################ FIM DO SCRIPT ########################
# Out:
# Selecione uma opção:
# 1. Executar o pipeline de treinamento
# 2. Executar o pipeline de teste
# 3. Sair
#
#
# Digite o número da sua escolha: 1
#
#
#
# Found 1200 images belonging to 4 classes.
# Found 200 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 7, 7, 2048)     │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,153,860 (92.14 MB)
#  Trainable params: 562,052 (2.14 MB)
#  Non-trainable params: 23,591,808 (90.00 MB)
# === Treinando apenas o topo (Transfer Learning) ===
#
# Epoch 1/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 280s 7s/step - accuracy: 0.5134 - loss: 1.1305 - val_accuracy: 0.2500 - val_loss: 1.7242 - learning_rate: 5.0000e-04
# Epoch 2/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7190 - loss: 0.6121
# Epoch 2: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 191s 5s/step - accuracy: 0.7194 - loss: 0.6114 - val_accuracy: 0.2500 - val_loss: 2.1516 - learning_rate: 5.0000e-04
# Epoch 3/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 198s 5s/step - accuracy: 0.7505 - loss: 0.5448 - val_accuracy: 0.4300 - val_loss: 1.5087 - learning_rate: 2.5000e-04
# Epoch 4/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 189s 5s/step - accuracy: 0.7777 - loss: 0.5027 - val_accuracy: 0.4400 - val_loss: 1.3209 - learning_rate: 2.5000e-04
# Epoch 5/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 183s 5s/step - accuracy: 0.7846 - loss: 0.5182 - val_accuracy: 0.5150 - val_loss: 1.1304 - learning_rate: 2.5000e-04
# Epoch 6/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 199s 5s/step - accuracy: 0.8105 - loss: 0.4349 - val_accuracy: 0.5650 - val_loss: 0.8900 - learning_rate: 2.5000e-04
# Epoch 7/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 201s 5s/step - accuracy: 0.8040 - loss: 0.4613 - val_accuracy: 0.5800 - val_loss: 0.7231 - learning_rate: 2.5000e-04
# Epoch 8/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 187s 5s/step - accuracy: 0.8128 - loss: 0.4372 - val_accuracy: 0.6800 - val_loss: 0.6036 - learning_rate: 2.5000e-04
# Epoch 9/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 192s 5s/step - accuracy: 0.8183 - loss: 0.4386 - val_accuracy: 0.7450 - val_loss: 0.5306 - learning_rate: 2.5000e-04
# Epoch 10/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 182s 5s/step - accuracy: 0.8199 - loss: 0.4064 - val_accuracy: 0.8050 - val_loss: 0.4500 - learning_rate: 2.5000e-04
# Epoch 11/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 176s 5s/step - accuracy: 0.8226 - loss: 0.4110 - val_accuracy: 0.7800 - val_loss: 0.4463 - learning_rate: 2.5000e-04
# Epoch 12/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 177s 5s/step - accuracy: 0.8350 - loss: 0.3998 - val_accuracy: 0.8050 - val_loss: 0.4156 - learning_rate: 2.5000e-04
# Epoch 13/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 177s 5s/step - accuracy: 0.8482 - loss: 0.3886 - val_accuracy: 0.8150 - val_loss: 0.3904 - learning_rate: 2.5000e-04
# Epoch 14/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8405 - loss: 0.3832
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 175s 5s/step - accuracy: 0.8401 - loss: 0.3837 - val_accuracy: 0.8100 - val_loss: 0.3954 - learning_rate: 2.5000e-04
# Epoch 15/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 176s 5s/step - accuracy: 0.8284 - loss: 0.3906 - val_accuracy: 0.8350 - val_loss: 0.3716 - learning_rate: 1.2500e-04
# Epoch 16/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 178s 5s/step - accuracy: 0.8054 - loss: 0.4298 - val_accuracy: 0.8350 - val_loss: 0.3641 - learning_rate: 1.2500e-04
# Epoch 17/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 179s 5s/step - accuracy: 0.8476 - loss: 0.3536 - val_accuracy: 0.8650 - val_loss: 0.3431 - learning_rate: 1.2500e-04
# Epoch 18/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8352 - loss: 0.3684
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 176s 5s/step - accuracy: 0.8354 - loss: 0.3682 - val_accuracy: 0.8400 - val_loss: 0.3537 - learning_rate: 1.2500e-04
# Epoch 19/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 175s 5s/step - accuracy: 0.8614 - loss: 0.3236 - val_accuracy: 0.8350 - val_loss: 0.3419 - learning_rate: 6.2500e-05
# Epoch 20/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8713 - loss: 0.3312
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 176s 5s/step - accuracy: 0.8709 - loss: 0.3316 - val_accuracy: 0.8400 - val_loss: 0.3469 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 19.
#
# === Iniciando Fine-Tuning ===
#
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 268s 7s/step - accuracy: 0.6960 - loss: 0.6857 - val_accuracy: 0.4550 - val_loss: 1.2980 - learning_rate: 1.0000e-05
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8001 - loss: 0.4428
# Epoch 2: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 252s 7s/step - accuracy: 0.8001 - loss: 0.4427 - val_accuracy: 0.4700 - val_loss: 1.8121 - learning_rate: 1.0000e-05
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8262 - loss: 0.3923
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 258s 7s/step - accuracy: 0.8261 - loss: 0.3921 - val_accuracy: 0.4900 - val_loss: 1.7191 - learning_rate: 5.0000e-06
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8765 - loss: 0.3100
# Epoch 4: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 263s 7s/step - accuracy: 0.8764 - loss: 0.3101 - val_accuracy: 0.4850 - val_loss: 1.3640 - learning_rate: 2.5000e-06
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 269s 7s/step - accuracy: 0.8706 - loss: 0.3179 - val_accuracy: 0.5100 - val_loss: 0.9536 - learning_rate: 1.2500e-06
# Restoring model weights from the end of the best epoch: 5.
#
# O modelo treinado foi salvo na pasta /content/drive/MyDrive/Colab Notebooks/VC/Classificacao_CNN/modelos/my_mobile_net_v2.keras
#
#
# Histórico salvo na pasta: /content/drive/MyDrive/Colab Notebooks/VC/Classificacao_CNN/resultados/
# Selecione uma opção:
# 1. Executar o pipeline de treinamento
# 2. Executar o pipeline de teste
# 3. Sair
#
#
# Digite o número da sua escolha: 2
#
#
#
# Found 200 images belonging to 4 classes.
# 7/7 - 29s - 4s/step
#
# Matriz salva na pasta: /content/drive/MyDrive/Colab Notebooks/VC/Classificacao_CNN/resultados/
# Métrica salva na pasta: /content/drive/MyDrive/Colab Notebooks/VC/Classificacao_CNN/resultados/
# Métrica salva na pasta: /content/drive/MyDrive/Colab Notebooks/VC/Classificacao_CNN/resultados/
# Métrica salva na pasta: /content/drive/MyDrive/Colab Notebooks/VC/Classificacao_CNN/resultados/
# Selecione uma opção:
# 1. Executar o pipeline de treinamento
# 2. Executar o pipeline de teste
# 3. Sair
#
#
# Digite o número da sua escolha: 3
# Execução finalizada!
